# %%
import requests

url = "https://assets.publishing.service.gov.uk/media/685bba977d72089d1997609b/PM25_Tables_2024.ods"
r = requests.get(url)
open("/Users/jonahwitte/Desktop/IS_477_Group_Project/data_2/pm25.ods", "wb").write(r.content)
# Out:
# 253182

# %%
import hashlib

with open("/Users/jonahwitte/Desktop/IS_477_Group_Project/data_2/pm25.ods", "rb") as f:
    file_hash = hashlib.sha256(f.read()).hexdigest()

print(file_hash)
# Out:
# 79ab706a202e2446c29e152b7dc5e2b4d68e75930bca95b04385986a43091f60
